# %%
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt 
df=pd.read_csv("C:/Users/Tejas Redkar/OneDrive/Desktop/Toyota.csv")
print(df)
# Out:
#       Unnamed: 0  Price   Age     KM FuelType   HP  MetColor  Automatic    CC  \
# 0              0  13500  23.0  46986   Diesel   90       1.0          0  2000
# 1              1  13750  23.0  72937   Diesel   90       1.0          0  2000
# 2              2  13950  24.0  41711   Diesel   90       NaN          0  2000
# 3              3  14950  26.0  48000   Diesel   90       0.0          0  2000
# 4              4  13750  30.0  38500   Diesel   90       0.0          0  2000
# ...          ...    ...   ...    ...      ...  ...       ...        ...   ...
# 1431        1431   7500   NaN  20544   Petrol   86       1.0          0  1300
# 1432        1432  10845  72.0     ??   Petrol   86       0.0          0  1300
# 1433        1433   8500   NaN  17016   Petrol   86       0.0          0  1300
# 1434        1434   7250  70.0     ??      NaN   86       1.0          0  1300
# 1435        1435   6950  76.0      1   Petrol  110       0.0          0  1600
#
#       Doors  Weight
# ...

# %%
data=df.corr()
data.head()
# Out:
#             Unnamed: 0     Price       Age  MetColor  Automatic        CC  \
# Unnamed: 0    1.000000 -0.738289  0.907090 -0.078616   0.066299 -0.184490
# Price        -0.738289  1.000000 -0.878407  0.112041   0.033081  0.165067
# Age           0.907090 -0.878407  1.000000 -0.099659   0.032573 -0.120706
# MetColor     -0.078616  0.112041 -0.099659  1.000000  -0.013973  0.029189
# Automatic     0.066299  0.033081  0.032573 -0.013973   1.000000 -0.069321
#
#               Weight
# Unnamed: 0 -0.414577
# Price       0.581198
# Age        -0.464299
# MetColor    0.057142
# Automatic   0.057249

# %%
df.hist()
# Out:
# array([[<AxesSubplot:title={'center':'Unnamed: 0'}>,
#         <AxesSubplot:title={'center':'Price'}>,
#         <AxesSubplot:title={'center':'Age'}>],
#        [<AxesSubplot:title={'center':'MetColor'}>,
#         <AxesSubplot:title={'center':'Automatic'}>,
#         <AxesSubplot:title={'center':'CC'}>],
#        [<AxesSubplot:title={'center':'Weight'}>, <AxesSubplot:>,
#         <AxesSubplot:>]], dtype=object)

# %%
#Following example plots a histogram or marks obtained by students in a class
# Four bins, 0-25,26-50,51-75,76-100 are defined
#The histogram shows number of students falling in this range
from matplotlib import pyplot as plt
import numpy as np
fig,ax = plt.subplots(1,1)
a = np.array([22,87,5,43,56,73,55,54,11,20,51,5,79,31,27])
ax.hist(a, bins = [0,25,50,75,100])
ax.set_title("Histogram of Result")
ax.set_xticks([0,25,50,75,100])
ax.set_xlabel('Marks')
ax.set_ylabel('No.of students')
plt.show()

# %%
import matplotlib.pyplot as plt
df.hist()
plt.show()

# %%
import seaborn as sns
corel=df.corr()
sns.heatmap(corel, vmax=.9, square=True)
sns.heatmap(corel, vmax=.9, annot=True,square=True)
plt.show()

# %%
#scatter plat demo
import matplotlib.pyplot as plt
plt.scatter(df['Age'],df['FuelType'],c='red')
plt.title("scatter plot of age vs FuelType of the cars")
plt.xlabel('Age(month)')
plt.ylabel('FuelType()')
plt.show()

# %%
df.dropna(inplace=True)

# %%
sns.set(style="darkgrid")
sns.regplot(x=df['Age'],y=df['KM'])
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# C:\Users\TEJASR~1\AppData\Local\Temp/ipykernel_34872/3552647334.py in <module>
#       1 sns.set(style="darkgrid")
# ----> 2 sns.regplot(x=df['Age'],y=df['KM'])
#       3 plt.show()
#
# D:\anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# D:\anaconda\lib\site-packages\seaborn\regression.py in regplot(x, y, data, x_estimator, x_bins, x_ci, scatter, fit_reg, ci, n_boot, units, seed, order, logistic, lowess, robust, logx, x_partial, y_partial, truncate, dropna, x_jitter, y_jitter, label, color, marker, scatter_kws, line_kws, ax)
#     861     scatter_kws["marker"] = marker
# ...

# %%
sns.set(style="darkgrid")
sns.regplot(x=df['Age'],y=df['KM'], fit_reg=False)
plt.show()

# %%
sns.lmplot(x='Age',y='KM',data=df,fit_reg=False,hue='FuelType',legend=True,palette="Set1")
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# C:\Users\TEJASR~1\AppData\Local\Temp/ipykernel_34872/2797398811.py in <module>
# ----> 1 sns.lmplot(x='Age',y='KM',data=df,fit_reg=False,hue='FuelType',legend=True,palette="Set1")
#       2 plt.show()
#
# D:\anaconda\lib\site-packages\seaborn\_decorators.py in inner_f(*args, **kwargs)
#      44             )
#      45         kwargs.update({k: arg for k, arg in zip(sig.parameters, args)})
# ---> 46         return f(**kwargs)
#      47     return inner_f
#      48
#
# ...

# %%
sns.boxplot(x=df['Automatic'],y=df['CC'])
plt.show()

# %%
sns.boxplot(x=df['FuelType'],y=df['CC'])
plt.show()

# %%
df.describe()
# Out:
#         Unnamed: 0         Price          Age     MetColor    Automatic  \
# count  1111.000000   1111.000000  1111.000000  1111.000000  1111.000000
# mean    707.868587  10774.997300    55.585959     0.675068     0.053105
# std     414.023750   3699.695538    18.829188     0.468561     0.224344
# min       0.000000   4350.000000     1.000000     0.000000     0.000000
# 25%     347.500000   8450.000000    43.000000     0.000000     0.000000
# 50%     703.000000   9900.000000    60.000000     1.000000     0.000000
# 75%    1069.500000  11950.000000    70.000000     1.000000     0.000000
# max    1435.000000  31275.000000    80.000000     1.000000     1.000000
#
#                 CC       Weight
# count  1111.000000  1111.000000
# mean   1569.463546  1073.870387
# std     185.935691    52.610513
# min    1300.000000  1000.000000
# 25%    1400.000000  1045.000000
# 50%    1600.000000  1070.000000
# 75%    1600.000000  1090.000000
# max    2000.000000  1615.000000
